# %%
import pandas as pd

# %%
df=pd.read_csv('ecommerce_dataset.csv')

# %%
df1=pd.read_csv('ecommerce_dataset1.csv')

# %%
df2=pd.DataFrame(df)

# %%
df3=pd.DataFrame(df1)

# %%
#Merge the Transactions and Products tables on the ProductID column to create a unified dataset

# %%
mer=pd.merge(df2,df3,on='ProductID')
mer
# Out:
#     TransactionID  CustomerID ProductID  OrderQuantity  OrderPrice  OrderDate  \
# 0             101        2001      P101              1         100   1/1/2023
# 1             102        2002      P102              2         105   1/2/2023
# 2             103        2003      P103              3         110   1/3/2023
# 3             104        2004      P104              4         115   1/4/2023
# 4             105        2005      P105              5         120   1/5/2023
# ..            ...         ...       ...            ...         ...        ...
# 95            196        2096      P196              6         575   4/6/2023
# 96            197        2097      P197              7         580   4/7/2023
# 97            198        2098      P198              8         585   4/8/2023
# 98            199        2099      P199              9         590   4/9/2023
# 99            200        2100      P200             10         595  4/10/2023
#
# ...

# %%
#Perform the integration of the Transactions and Products tables and display the first 5
#rows of the integrated dataset.

# %%
print(mer.head(5))
# Out:
#    TransactionID  CustomerID ProductID  OrderQuantity  OrderPrice OrderDate  \
# 0            101        2001      P101              1         100  1/1/2023
# 1            102        2002      P102              2         105  1/2/2023
# 2            103        2003      P103              3         110  1/3/2023
# 3            104        2004      P104              4         115  1/4/2023
# 4            105        2005      P105              5         120  1/5/2023
#
#   CustomerLocation  ProductName     Category
# 0         New York  Product 101  Electronics
# 1      Los Angeles  Product 102    Furniture
# 2          Chicago  Product 103  Kitchenware
# 3          Houston  Product 104     Clothing
# 4         New York  Product 105  Electronics

# %%
#Write a Python code snippet to identify and remove duplicate records from the dataset.

# %%
mer.drop_duplicates()
# Out:
#     TransactionID  CustomerID ProductID  OrderQuantity  OrderPrice  OrderDate  \
# 0             101        2001      P101              1         100   1/1/2023
# 1             102        2002      P102              2         105   1/2/2023
# 2             103        2003      P103              3         110   1/3/2023
# 3             104        2004      P104              4         115   1/4/2023
# 4             105        2005      P105              5         120   1/5/2023
# ..            ...         ...       ...            ...         ...        ...
# 95            196        2096      P196              6         575   4/6/2023
# 96            197        2097      P197              7         580   4/7/2023
# 97            198        2098      P198              8         585   4/8/2023
# 98            199        2099      P199              9         590   4/9/2023
# 99            200        2100      P200             10         595  4/10/2023
#
# ...

# %%
#How would you handle outliers in the Price column using the interquartile range (IQR)
#method?

# %%
q1=df['OrderPrice'].quantile(0.25)
q1
# Out:
# 223.75

# %%
q3=df['OrderPrice'].quantile(0.75)
q3
# Out:
# 471.25

# %%
IQR=q3-q1

# %%
ib=q1-1.5*IQR

# %%
ub=q3+1.5*IQR

# %%
outlier=((df[['OrderPrice']]<ib) | (df[['OrderPrice']]>ub)).any(axis=1)

# %%
cleaned=df[~outlier]

# %%
cleaned
# Out:
#     TransactionID  CustomerID ProductID  OrderQuantity  OrderPrice  OrderDate  \
# 0             101        2001      P101              1         100   1/1/2023
# 1             102        2002      P102              2         105   1/2/2023
# 2             103        2003      P103              3         110   1/3/2023
# 3             104        2004      P104              4         115   1/4/2023
# 4             105        2005      P105              5         120   1/5/2023
# ..            ...         ...       ...            ...         ...        ...
# 95            196        2096      P196              6         575   4/6/2023
# 96            197        2097      P197              7         580   4/7/2023
# 97            198        2098      P198              8         585   4/8/2023
# 98            199        2099      P199              9         590   4/9/2023
# 99            200        2100      P200             10         595  4/10/2023
#
#    CustomerLocation
# ...

# %%
#Perform Min-Max normalization on the Quantity and Price columns and display the
#transformed dataset.

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler=MinMaxScaler()

# %%
df['Quantity_Normalized']=scaler.fit_transform(df[['OrderQuantity']])

# %%
df['Price_Normalized']=scaler.fit_transform(df[['OrderPrice']])

# %%
df
# Out:
#     TransactionID  CustomerID ProductID  OrderQuantity  OrderPrice  OrderDate  \
# 0             101        2001      P101              1         100   1/1/2023
# 1             102        2002      P102              2         105   1/2/2023
# 2             103        2003      P103              3         110   1/3/2023
# 3             104        2004      P104              4         115   1/4/2023
# 4             105        2005      P105              5         120   1/5/2023
# ..            ...         ...       ...            ...         ...        ...
# 95            196        2096      P196              6         575   4/6/2023
# 96            197        2097      P197              7         580   4/7/2023
# 97            198        2098      P198              8         585   4/8/2023
# 98            199        2099      P199              9         590   4/9/2023
# 99            200        2100      P200             10         595  4/10/2023
#
# ...

# %%
#Apply one-hot encoding to the Category column and show the updated dataset.

# %%
encoded=pd.get_dummies(df,columns=['CustomerLocation'])
encoded
# Out:
#     TransactionID  CustomerID ProductID  OrderQuantity  OrderPrice  OrderDate  \
# 0             101        2001      P101              1         100   1/1/2023
# 1             102        2002      P102              2         105   1/2/2023
# 2             103        2003      P103              3         110   1/3/2023
# 3             104        2004      P104              4         115   1/4/2023
# 4             105        2005      P105              5         120   1/5/2023
# ..            ...         ...       ...            ...         ...        ...
# 95            196        2096      P196              6         575   4/6/2023
# 96            197        2097      P197              7         580   4/7/2023
# 97            198        2098      P198              8         585   4/8/2023
# 98            199        2099      P199              9         590   4/9/2023
# 99            200        2100      P200             10         595  4/10/2023
#
# ...
